# %% [markdown]
# <a href="https://colab.research.google.com/github/kmc3661/-KIRD-Data-Analysis-Practice-with-Pandas-NumPy/blob/main/Numpy_%EC%8B%A4%EC%8A%B5_%EC%98%88%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 📦 문제 0. 배열 생성
#
# ✅ 문제
#
# 다음 점수를 NumPy 배열로 변환 후 출력하시오
#
# [65, 72, 80, 90, 55, 78, 85, 60, 88, 92]

# %% [markdown]
# 📦 문제 1. 기본 통계
#
# ✅ 문제
#
# 1. 점수 배열에서 평균, 최댓값, 최솟값을 구하시오.
# 2. 80점 이상 점수만 출력하시오
# 3. 평균보다 높은 점수만 출력하시오

# %% [markdown]
# 📦 문제 2. 구간 분류
#
# ✅ 문제
#
# 점수를 다음 기준으로 분류 후 결과를 출력하시오.
#
# *   80 이상 → High
# *   60~79 → Medium
# *   60 미만 → Low

# %% [markdown]
# 📦 문제 3. 데이터 생성
#
# ✅ 문제
#
# 1. 0~100 사이 정수 난수 20개 생성하시오.
# 2. 평균 70, 표준편차 10인 정규분포 데이터 100개 생성 후 출력하시오
# 3. 생성한 정규분포 데이터를 아래 조건에 맞춰 히스토그램으로 나타내시오
# *   x축: score, y축: count
# *   title: score distribution

# %% [markdown]
# 📦 문제 4. 2차원 배열
#
# ✅ 문제
#
# 다음은 3명의 학생의 3과목 점수이다.
# (각 행은 학생, 각 열은 과목을 의미한다)
#
# 학생1: [80, 70, 90]
# 학생2: [60, 75, 85]
# 학생3: [90, 88, 92]
#
# 1. 이 데이터를 NumPy 배열로 생성하시오.
# 2. 각 과목의 평균을 구하시오.
# 3. 각 학생의 평균을 구하시오.
# 4. 80점 이상 값만 출력하시오.

# %% [markdown]
# 📦 문제 5. 그래프 시각화
#
# ✅ 문제
#
# 학생별 평균 점수를 선 그래프로 나타내시오.
