# %% [markdown]
# <a href="https://colab.research.google.com/github/kmc3661/-KIRD-Data-Analysis-Practice-with-Pandas-NumPy/blob/main/%5BKIRD%5D%EC%8B%A4%EC%8A%B5_%EC%98%88%EC%A0%9C_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 실습: “공부시간과 성적의 관계 분석”
# 🎯 전체 목표
#
# 다음 데이터를 이용하여
# 👉 “공부시간이 많으면 성적이 높은가?”라는 가설을 검증해보자.

# %% [markdown]
# 📦 [문제 0] 데이터 준비
#
# 다음과 같은 학생 데이터가 주어진다.
#
# Name: 학생 이름
#
# Age: 나이
#
# Score: 시험 점수
#
# StudyTime: 공부 시간
#
# ---
# "Name": ["A","B","C","D","E","F","G","H","I","J"],
#     "Age": [22, 25, 19, 35, 28, 40, 30, 21, 23, 27],
#     "Score": [85, 90, 70, 88, 95, 60, 77, 82, 91, 73],
#     "StudyTime": [2, 3, 1, 4, 5, 1, 2, 3, 4, 2]
#
#
# ---
#
#
# 👉 이 데이터를 pandas DataFrame으로 생성하고 출력하시오.

# %% [markdown]
# 🧪 [문제 1] 데이터 탐색
#
# 데이터를 분석하기 전에 기본 정보를 확인해보자.
#
# 요구사항
#
# 1. 데이터의 상위 5개 행을 출력하시오.
#
# 2. 전체 학생들의 평균 점수를 구하시오.

# %% [markdown]
# 🧪 [문제 2] 가설 설정 및 그룹 나누기
#
# 다음과 같은 가설을 세운다.
#
# 👉 “공부를 많이 하면 점수가 더 높을 것이다.”
#
# 이를 검증하기 위해 학생을 두 그룹으로 나누자.
#
# 요구사항
#
# 1. StudyTime을 기준으로 새로운 열 Group을 추가하시오.
#
# ---
#
# 기준은 다음과 같다:
#
# StudyTime ≥ 3 → "High"
#
# StudyTime < 3 → "Low"
#
# ---
#
# 2. 결과를 출력하시오.

# %% [markdown]
# 🧪 [문제 3] 가설 검증 (통계)
#
# 그룹별로 점수 차이가 있는지 확인해보자.
#
# 요구사항
#
# 1. Group별 평균 점수를 구하시오.
#
# 2. 결과를 출력하시오.
#
# 👉 힌트: groupby() 사용

# %% [markdown]
# 🧪 [문제 4] 시각화로 비교하기
#
# 그룹별 평균 점수를 그래프로 비교해보자.
#
# 요구사항
#
# 1. 그룹별 평균 점수를 막대그래프로 나타내시오.
#
# 2. 그래프의 제목, x축, y축 라벨을 설정하시오.
#
# 👉 목표: High vs Low 차이를 직관적으로 확인

# %% [markdown]
# 🧪 [문제 5] 전체 관계 시각화
#
# 공부시간과 점수의 관계를 한눈에 확인해보자.
#
# 요구사항
#
# 1. StudyTime을 x축, Score를 y축으로 하는 산점도를 그리시오.
#
# 👉 목표: 패턴 및 이상치 확인
