# %% [markdown]
# <a href="https://colab.research.google.com/github/kmc3661/-KIRD-Data-Analysis-Practice-with-Pandas-NumPy/blob/main/%5BKIRD%5D%EC%8B%A4%EC%8A%B5_%EC%98%88%EC%A0%9C_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🧪 실습: 타이타닉 생존자 데이터 분석
#
# 📦 [문제 0] 데이터 불러오기
#
# ✅ 문제
#
# titanic.csv 파일을 읽어서 DataFrame으로 저장하고
# 상위 5개 데이터를 출력하시오.

# %% [markdown]
# 🧪 [문제 1] 기본 통계 확인
#
# ✅ 문제
#
# 1. 승객의 평균 나이를 구하시오.
#
# 2. 최고 나이를 구하시오.
#
# 3. 생존자의 비율을 구하시오.

# %% [markdown]
# 🧪 [문제 2] 가설 설정
#
# 👉 “여성이 남성보다 생존률이 높다”
#
# ✅ 문제
#
# 성별(Sex) 기준으로 생존률을 구하시오.

# %% [markdown]
# 🧪 [문제 3] 시각화 (성별 생존률)
#
# ✅ 문제
#
# 성별 생존률을 막대그래프로 나타내시오.

# %% [markdown]
# 🧪 [문제 4] 또 다른 가설
#
# 👉 “상위 클래스일수록 생존률이 높다”
#
# ✅ 문제
#
# Pclass(좌석 등급)별 생존률을 구하시오.

# %% [markdown]
# 🧪 [문제 5] 시각화 (클래스별 생존률)
#
# ✅ 문제
#
# 클래스 별 생존률을 선 그래프로 나타내시오.

# %% [markdown]
# 🧪 [문제 6] 나이와 생존 관계
#
# 👉 “어린 사람이 더 많이 생존했을 것이다”
#
# ✅ 문제
#
# 20세 미만과 20세 이상 그룹의 생존률을 출력하시오.

# %% [markdown]
# 🧪 [문제 7] 나이와 좌석 등급 관계
#
# ✅ 문제
#
# 승객의 나이(Age)와 좌석 등급(Pclass)의 관계를 시각화하시오.
#
# 요구사항
#
# 1. x축: 좌석 등급(Pclass)
#
# 2. y축: 나이(Age)
#
# 3. 막대그래프를 그리시오.
#
# 4. 그래프의 제목과 축 이름을 설정하시오.

# %% [markdown]
# 🧪 [문제 8] 조건 만족 데이터 탐색
#
# ✅ 문제
#
# 다음 조건을 모두 만족하는 승객의 수를 구하시오:
#
# 1. 여성
# 2. 1등석
# 3. 생존한 사람

# %% [markdown]
# 🧪 [문제 9] 생존자와 사망자의 나이 분포 시각화
#
# ✅ 문제
#
# 성별(Sex)과 좌석 등급(Pclass)에 따른 생존률을 그래프로 비교하시오
#
# 요구사항
#
# 1. 성별과 좌석등급으로 그룹을 나누시오
#
# 2. 각 그룹의 생존률을 계산하시오
#
# 3. 그래프로 나타내시오 (x축: Pclass, y축: Survival Rate)
